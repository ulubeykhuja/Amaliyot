# %% [markdown]
# <a href="https://colab.research.google.com/github/ulubeykhuja/Amaliyot/blob/main/survey_merg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("/content/respond.xlsx")
df2 = pd.read_excel("/content/ssurvey.xlsx")

# %%
merged_df = pd.merge(df1, df2, left_on='telegram_id', right_on='ID рақамингиз', how='inner')

# %%
print(merged_df.head())
# Out:
#    telegram_id     full_name  region district        mahalla birth_year  \
# 0    693834062         Jasur  Жиззах    Зомин          Nihol       1990
# 1   1480335794  ABDULAZIZBEK  Жиззах   Бахмал    Fidokor MFY       1997
# 2   1620426632        Sardor  Жиззах   Бахмал    Fidokor MFY       1997
# 3   7753871756     Абдулатиф  Жиззах   Бахмал       Истиклол       1995
# 4   5699253911     Saidasror  Жиззах   Бахмал  Yangibog' MFY       2004
#
#   gender education      employment_status            sector  ...        _id  \
# 0  Эркак      Олий      Доимий иш (тўлиқ)  Давлат секторида  ...  615207039
# 1  Эркак      Олий      Доимий иш (тўлиқ)  Давлат секторида  ...  615208014
# 2  Эркак      Олий      Доимий иш (тўлиқ)  Давлат секторида  ...  615210051
# 3  Эркак      Олий  Ўзини-ўзи банд қилган               NaN  ...  615222134
# 4  Эркак      Олий              Талабаман               NaN  ...  615230511
#
#                                   _uuid    _submission_time  \
# ...

# %%
merged_df.to_excel("merged_file.xlsx", index=False)

# %% [markdown]
# <a href="https://colab.research.google.com/github/ulubeykhuja/Amaliyot/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%2210_MA%CA%BCLUMOTLARGA_ISHLOV_BERISH_10_11_HTML_JSON_API_o%CA%BBqish_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/h4PPC71.png)
# #**10-modul. Maʼlumotlarga ishlov berish. Fayllar va maʼlumotlar ombori**
# #10.11. Veb sahifalardan oʻqish. JSON va API
# **Bu vazifalarni bajargach, veb sahifalardan maʼlumot olish, JSON bilan ishlash va API soʻrovlarini yuborish koʻnikmalarini egallaysiz.**

# %% [markdown]
# #1-topshiriq
# 1. Pandas kutubxonasidan foydalanib, quyida berilgan link ichidan barcha jadvallarni o‘qing va roʻyxat shaklida saqlang.
#  * https://en.wikipedia.org/wiki/Fossil_fuel_exporters
# 2. Har bir jadvalning birinchi 1 qatorini ekranga chiqaring.

# %%
#javobni shu yerda yozing.

# import
import pandas as pd
import requests

# read
url = "https://en.wikipedia.org/wiki/Fossil_fuel_exporters"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36'}
response = requests.get(url, headers=headers)

df = pd.read_html(response.text)

#print
print(f"Umumiy jadval soni: {len(df)} ta\n")

# Har bir jadvalning birinchi 1 qatorini ekranga chiqaring.
for i, table in enumerate(df):
    print(f"Jadval {i+1} ning birinchi qatori:")
    print(table.head(1))
    print("-" * 50)
# Out:
# Umumiy jadval soni: 7 ta
#
# Jadval 1 ning birinchi qatori:
#     0                                                  1
# 0 NaN  This article needs to be updated. Please help ...
# --------------------------------------------------
# Jadval 2 ning birinchi qatori:
#    Rank Country/region                       Oil - exports Date of information
# 0     1   Saudi Arabia  6,658,642 bbl/d (1,058,639.5 m3/d)           2020 est.
# --------------------------------------------------
# Jadval 3 ning birinchi qatori:
#    Rank Country/region  Natural gas - exports (cu m) Date of information
# 0     1         Russia                  199928345000           2020 est.
# --------------------------------------------------
# Jadval 4 ning birinchi qatori:
#    Rank    Country  Coal - exports (thousand short tons)  Date of information
# 0     1  Indonesia                                451520                 2020
# --------------------------------------------------
# Jadval 5 ning birinchi qatori:
#   vteLists of countries by energy rankings  \
# 0                              Fossil Fuel
#
#           vteLists of countries by energy rankings.1
# 0  Petroleum All Production Consumption Exports I...
# --------------------------------------------------
# Jadval 6 ning birinchi qatori:
#            0                                                  1
# 0  Petroleum  All Production Consumption Exports Imports Res...
# --------------------------------------------------
# Jadval 7 ning birinchi qatori:
#          0                                   1
# 0  Uranium  All Production Generation Reserves
# --------------------------------------------------
# /tmp/ipython-input-1146288392.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(response.text)

# %% [markdown]
# #2-topshiriq
# Yuqorida yaratilgan jadvallar roʻyxatidan eng uzunini `largest_data.csv` fayliga saqlang.

# %%
#javobni shu yerda yozing.

# eng uzun jadval
largest_table = max(df, key=len)

# Eng uzun jadvalni CSV faylga saqlash
largest_table.to_csv("largest_data.csv", index=False)

# print
print(largest_table.head(3))
# Out:
#   vteLists of countries by energy rankings  \
# 0                              Fossil Fuel
# 1                                Petroleum
# 2                              Natural gas
#
#           vteLists of countries by energy rankings.1
# 0  Petroleum All Production Consumption Exports I...
# 1  All Production Consumption Exports Imports Res...
# 2  All Production Consumption Exports Imports Res...

# %% [markdown]
# #3-topshiriq
# 1. Quyidagi link orqali json maʼlumotni yuklab oling va uni climate_change_co2.json nomi bilan saqlang.
#  * https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/json_data.json
# 2. Maʼlumotlar boshidan 5 ta qatorni ekranga chiqaring!

# %%
url = "https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/json_data.json"
#javobni shu yerda yozing.

#read
response = requests.get(url)
response.raise_for_status()

#save to json
with open("climate_change_co2.json", "w", encoding="utf-8") as f:
    f.write(response.text)

#read json
df = pd.read_json("climate_change_co2.json")

# Maʼlumotlar boshidan 5 ta qatorni ekranga chiqaring!
print(df.head())
# Out:
#    Year  Total  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 0  2010   9167      1702         3114        3842     450           59
# 1  2009   8740      1585         3056        3620     413           66
# 2  2008   8783      1631         3122        3571     388           71
# 3  2007   8566      1572         3081        3464     382           68
# 4  2006   8370      1525         3089        3339     356           61
#
#    Per Capita
# 0        1.33
# 1        1.28
# 2        1.30
# 3        1.28
# 4        1.27

# %% [markdown]
# #4-topshiriq
# 1. Quyida berilgan linkga `get` soʻrovini yuborish orqali `json` maʼlumotlarini `posts.json` fayliga saqlang.
#   * https://jsonplaceholder.typicode.com/posts/
# 2. Ushbu maʼlumotlarni dataframe koʻrinishida saqlang va tasodifiy 5 ta qatorni ekranga chiqaring.

# %%
url = "https://jsonplaceholder.typicode.com/posts/"
#javobni shu yerga yozing.
# get soʻrovini yuborish orqali json maʼlumotlarini posts.json fayliga saqlang.

response = requests.get(url)
response.raise_for_status()
# save to json
with open("posts.json", "w", encoding="utf-8") as f:
    f.write(response.text)
# read json
df = pd.read_json("posts.json")

# tasodifiy 5 ta qatorni ekranga chiqaring.
print(df.sample(5, random_state=42))
# Out:
#     userId  id                                              title  \
# 83       9  84  optio ipsam molestias necessitatibus occaecati...
# 53       6  54         sit asperiores ipsam eveniet odio non quia
# 70       8  71                  et iusto veniam et illum aut fuga
# 45       5  46                 aut quo modi neque nostrum ducimus
# 44       5  45  ut numquam possimus omnis eius suscipit laudan...
#
#                                                  body
# 83  sint molestiae magni a et quos\neaque et quasi...
# 53  totam corporis dignissimos\nvitae dolorem ut o...
# 70  occaecati a doloribus\niste saepe consectetur ...
# 45  voluptatem quisquam iste\nvoluptatibus natus o...
# 44  est natus reiciendis nihil possimus aut provid...
